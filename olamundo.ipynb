# %% [markdown]
# <a href="https://colab.research.google.com/github/Marciobarrosetec/PA-1E-grupo-B/blob/main/olamundo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Olá mundo!")
# Out:
# Olá mundo!
