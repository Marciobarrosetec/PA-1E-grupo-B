# %% [markdown]
# <a href="https://colab.research.google.com/github/Marciobarrosetec/PA-1E-grupo-B/blob/main/Aula_dia_25_03_PA_1E_grupo_B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Decisões

# Entrada
a = int (input("digitar um número: "))
b = int (input("digitar um número: "))


if a >= b:

  print (f"{a} é maior ou igual a {b}.")

else:

  print (f"{a} é menor que  {b}.")
# Out:
# digitar um número: 3
# digitar um número: 3
# 3 é maior ou igual a 3.

# %%
# Escrever um programa que recebe 04 notas do aluno, calcula a média e mostra se o aluno foi aprovado, recuperação ou reprovado.


#Entrada
print ("digite suas notas AQUI,  valores de 01 a 10!")
nota1 = float (input("digite a nota do 1º bimestre: "))
nota2 = float (input("digite a nota do 2º bimestre: "))
nota3 = float (input("digite a nota do 3º bimestre: "))
nota4 = float (input("digite a nota do 4º bimestre: "))

# processamento

resultado = (nota1 + nota2 + nota3 + nota4) / 4

if resultado >= 7:

  print (f"A média das suas notas foi {resultado}, você foi aprovado.")

elif resultado >= 5:

  print(f"A média das suas notas foi {resultado}, você terá que fazer recuperação.")

else:

  print(f"A média das suas notas foi {resultado}, você foi reprovado.")

# %%
# Fazer uma calculadora simple com as 04 operações


print("-------------- MENU ------------")
print("")
print (" Opção - 1 = SOMA")
print (" Opçao - 2 = SUBTRAÇÃO")
print (" Opção - 3 = MULTIPLCAÇÃO")
print (" Opção - 4 = DIVISÃO")
print("")

Opcao = int (input("Digite a opção: "))


if Opcao < 0 or Opcao > 4:

  print("digite uma opção válida!")
  print("")

  Opcao = int (input("Digite a opção: "))

  a = float (input("digite um número: "))
  b = float (input("digite um número: "))


elif Opcao ==1:

  a = float (input("digite um número: "))
  b = float (input("digite um número: "))
  print("")
  print("---------------SOMA----------------------")
  print("")
  print(f"A soma de {a} e {b} é igual a : {a + b}")

elif Opcao ==2:

  a = float (input("digite um número: "))
  b = float (input("digite um número: "))
  print("")
  print("---------------SUBTRAÇÃO----------------------")
  print("")
  print(f"A subtração de {a} e {b} é igual a : {a - b}")

elif Opcao ==3:

  a = float (input("digite um número: "))
  b = float (input("digite um número: "))
  print("")
  print("---------------MULTIPLICAÇÃO----------------------")
  print("")
  print(f"A multiplicação de {a} e {b} é igual a : {a * b}")

elif Opcao ==4:

  a = float (input("digite um número: "))
  b = float (input("digite um número: "))
  print("")
  print("---------------DIVISÃO----------------------")
  print("")
  print(f"A divisão de {a} e {b} é igual a : {a / b}")

else:

  print ("digite uma opção válida!")
# Out:
# -------------- MENU ------------
#
#  Opção - 1 = SOMA
#  Opçao - 2 = SUBTRAÇÃO
#  Opção - 3 = MULTIPLCAÇÃO
#  Opção - 4 = DIVISÃO
#
# Digite a opção: 4
# digite um número: 20
# digite um número: 5
#
# ---------------DIVISÃO----------------------
#
# A divisão de 20.0 e 5.0 é igual a : 4.0
